# %%
import numpy as np 
import talib 
close = np.random.random(100)
ema = talib.EMA(close, 5)
ema
# Out:
# array([       nan,        nan,        nan,        nan, 0.24900821,
#        0.29269631, 0.35110917, 0.27932015, 0.38724569, 0.31023461,
#        0.25163474, 0.18529536, 0.18994623, 0.20355717, 0.33392003,
#        0.27531922, 0.22407643, 0.33145924, 0.52404046, 0.43171544,
#        0.38567249, 0.53841381, 0.39744866, 0.34156315, 0.31298427,
#        0.2411529 , 0.28308121, 0.22045718, 0.47054729, 0.41592304,
#        0.36232132, 0.523305  , 0.50483532, 0.65014487, 0.6788753 ,
#        0.52003078, 0.52637331, 0.49474029, 0.38623543, 0.38901317,
#        0.36793546, 0.38715577, 0.56232234, 0.40077704, 0.47759815,
#        0.61760434, 0.68692607, 0.50936099, 0.39315542, 0.3856277 ,
#        0.41158817, 0.3292141 , 0.47910835, 0.33725265, 0.50928208,
#        0.44379728, 0.34669632, 0.35745891, 0.49038396, 0.60106547,
#        0.50949761, 0.63996018, 0.75013793, 0.76772554, 0.52215401,
#        0.62218837, 0.48770356, 0.56009919, 0.53761211, 0.41665174,
# ...
